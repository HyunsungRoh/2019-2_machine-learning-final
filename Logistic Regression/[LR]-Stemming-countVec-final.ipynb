# %% [markdown]
# ### 0. Data Loading
#
# 프로젝트 폴더에서 데이터를 불러온다

# %%
import re
import pandas as pd
import numpy as np 
import json


stemFile ='train_data.csv'
stemInput= pd.read_csv(stemFile)

# %%
clauses = list(stemInput['clauses'])
train_label = np.array(stemInput['label'])

# %%
clauses
# Out:
# ['contractor engin record shall sign seal draw cover sheet calcul depart record set',
#  'modif repair drill shaft micropil',
#  'product certif materi requir product certif identifi accept subsect section',
#  'propos submit mail enclos propos seal envelop mark direct',
#  'submit measur test support data accept',
#  'depart reserv right delet bid portion util reloc work contract',
#  'upon final accept verif final pay record govern send sf public voucher purchas servic person final voucher releas claim document',
#  'content written claim condit preced contractor entitl addit compens time extens contract claim contractor shall submit certifi written claim depart includ individu claim minimum follow inform',
#  'submit written document inspect engin within hour inspect',
#  'far claus util small busi concern far claus prompt payment construct contract term subcontract includ site site work suppli contract',
#  'internet bid submitt bidder shall execut propos bidder digit id enter firm bid offic street address bidder inform tab depart bid softwar',
#  'engin judg propos infring structur integr maintain structur contractor engin record perform technic assess submit engin approv',
#  'contractor shall hold harmless indemnifi defend depart contractor other priviti therewith claim liabil oblig loss reason expens relat thereto includ reason attorney fee incur suffer breach forego grant regardless whether intellectu properti right disclos contractor pursuant',
#  'weed introduc releas prohibit aquat plant plant pest noxiou weed project limit result clear grub earthwork grass mulch',
#  'hold addit progress meet upon mutual agreement',
#  'depart charg cost depart incur contractor default includ cost complet work contract contractor',
#  'event either depart contractor contend plan quantiti item error addit less compens therebi due claimant shall submit expens evid form accept verifi measur calcul',
#  'gener shop draw requir prequalifi item',
#  'provid resolut qualiti color text line clearli discern',
#  'clearli label number sheet submitt indic total number sheet seri',
#  'payment made actual quantiti work perform accept materi furnish accord contract',
#  'submit paper set draw electron set draw support calcul',
#  'prolong suspens engin suspend contractor oper indefinit period store materi manner obstruct imped travel public unnecessarili becom damag way',
#  'materi sourc restor restor govern provid sourc accord approv sourc develop plan',
#  'engin inspect check accept contractor field note layout work reliev contractor respons achiev line grade dimens shown contract document',
#  'sequenc oper open work prejudic work alreadi start',
#  'shop draw structur steel miscellan metal submit shop draw structur steel miscellan metal',
#  'take everi reason precaut prevent damag deterior work perform',
#  'approv materi sourc constitut accept materi submit sourc',
#  'deduct quantiti outsid design stake limit',
#  'accept co may reliev contractor respons maintain accept work',
#  'limit construct begin end project detail plan',
#  'construct affect public safeti temporari brace requir shown plan altern temporari brace system propos submit plan calcul sign seal specialti engin includ stabil analysi design temporari brace member connect',
#  'prepar bid follow requir far claus prepar bid construct',
#  'cross necessari cross exist road street includ specif exist travel lane divid highway within limit project',
#  'gener submit bid guarante sf bid bond bid guarante corpor individu sureti sign sf princip make statement form pledg secur',
#  'submit product certif manufactur shipment materi includ follow',
#  'paragraph florida statut requir depart adopt regul determin default provid contractor pay liquid damag depart failur contractor complet contract work',
#  'contractor sole directli respons owner oper properti damag injuri expens loss inconveni delay caus contractor oper',
#  'contract time adjust accord',
#  'applic project includ limit inform',
#  'legal complianc area use',
#  'formwork scaffold contractor sole respons safe instal use formwork scaffold',
#  'ensur equip rental agreement includ oper personnel employe independ contractor sole proprietorship partner cover insur requir florida worker compens law',
#  'select sourc submit accept materi notifi co propos sourc deliveri project expedit materi inspect test',
#  'includ support document requir specif standard plan apl approv process',
#  'includ detail propos subsequ detail shop draw submitt',
#  'condit preced extens contract time contractor must submit engin',
#  'enclos seal envelop second outer envelop address depart place design',
#  'pretest manufactur submit certifi manufactur test result engin qualif use depart project',
#  'depart invit bidder author agent interest parti attend',
#  'basi depart compar amount bid make result comparison avail public',
#  'notwithstand contractor shall formal right whatsoev extra compens time extens deem due contractor caus unless contractor follow procedur set forth',
#  'submit applic must identifi product product packag product label requir specif',
#  'florida statut amend prescrib certain limit use supplement agreement part contract',
#  'stop order co may order perform work stop either whole part period deem necessari due follow',
#  'make check money order payabl agenc issu solicit',
#  'contact local nation forest ranger district unit state depart agricultur usda offic proper permit subsequ approv',
#  'gnss work plan shall describ gnss enabl autom machin guidanc technolog integr technolog employ project',
#  'built draw certifi survey must submit pdf file format scale contract plan format inch inch sheet satisfi requir special',
#  'contractor shall requir subcontractor submit certif accord',
#  'subcontract cost includ support data requir',
#  'printer malfunct break contractor may manual weigh record mass hour provid method weigh meet contract requir',
#  'contractor oblig except set forth bond except provid',
#  'level select load level reveal vehicl haul less approv volum reduc quantiti materi receiv sinc last level load ratio current level load volum agre volum',
#  'pend depart execut formal supplement agreement implement approv propos contractor shall remain oblig perform work accord term exist contract',
#  'detail factual statement claim provid necessari date locat item work affect includ claim',
#  'gener engin calcul plan quantiti use length base station station dimens width base neat line shown plan',
#  'claim extra work contractor deem addit compens time extens due work materi expressli provid contract written direct expressli order engin pursuant contractor shall submit written notif engin intent make claim',
#  'allow final judgment stand unsatisfi period ten',
#  'bidder request replac propos form depart attempt provid replac overnight deliveri electron transmitt file',
#  'determin estim net save depart reserv right disregard contract bid price judgment engin price repres fair measur valu work perform delet',
#  'scope payment payment contract work provid either directli indirectli pay item list bid schedul',
#  'use feder land propos submit approv letter special use permit applic feder land manag agenc',
#  'unresolv claim exist claim propos reserv right claim list descript claim amount claim releas claim document',
#  'submit origin record written certif deliveri materi end shift',
#  'provid superintend regardless amount work sublet',
#  'materi proport measur paid mass provid one follow',
#  'applic copi notic requir far claus g',
#  'contractor provid indemnif contractor shall indemnifi hold harmless depart offic employe liabil damag loss cost includ limit reason attorney fee extent caus neglig reckless intent wrong misconduct contractor person employ util contractor perform construct contract',
#  'includ provis subcontract requir subcontractor includ subcontract other',
#  'fabric draw bear assembl',
#  'depart pay estim less sum depart may deduct retain provis contract soon practic final accept work along execut supplement agreement receiv final accept',
#  'structur without temporari support temporari girder brace system perform minimum weekli inspect brace diaphragm cross frame place',
#  'subcontract involv site labor requir subcontractor complet part ii sf complet form may provid govern',
#  'disagr item submit full explan includ item amount',
#  'bidder shall examin bore data avail make interpret subsoil investig preliminari data shall base bid sole opinion condit like encount',
#  'risk loss damag expens aris natur prosecut work includ compens provid pay item',
#  'resum activ specif author engin',
#  'contractor shall design primari engin respons propos design design contractor engin record propos design',
#  'specif stake requir perform new base construct part project set stake establish line grade subgrad base curb relat item interv along line work',
#  'specif plan special provis supplementari document integr part contract requir occur one bind though occur',
#  'maximum obtain pay factor categori ii qualiti characterist less lot payment base lowest singl pay factor categori ii qualiti characterist',
#  'depart grant time extens contract delay due fault neglig contractor',
#  'preserv present resolut claim contractor may time otherwis time submit notic intent claim preliminari time extens request pursuant',
#  'includ limit design materi fabric method oper modif',
#  'depart may purchas actual cost accept materi suppli procur work depart inspect test approv contractor incorpor work',
#  'liquid damag assess follow',
#  'mandatori claim record submit engin notic intent file claim extra work delay contractor must keep daili record labor materi equip cost incur oper affect extra work delay',
#  'upon failur compli promptli order engin made provis articl engin author defect materi remov replac forc deduct cost remov replac money due becom due contractor',
#  'includ detail note addit inform discov construct note addit revis locat charact dimens work',
#  'side bank underdrain filter exfiltr trench locat dimens elev includ clean out pipe connect control structur point discharg receiv water',
#  'submit request suspens oper write engin identifi specif date begin end suspens',
#  'limit coverag describ herein shall appli fulli work oper perform contract may share diminish claim unrel contract',
#  'depart plan plan consist gener draw show detail necessari give comprehens idea construct contempl',
#  'set grade stake locat engin direct facilit check subgrad base pavement elev crossov intersect irregular shape area',
#  'daili record must identifi oper affect extra work delay specif locat work affect extra work delay nearli possibl',
#  'credit given even though contractor may receiv train program fund sourc provid sourc specif prohibit contractor receiv form compens',
#  'determin quantiti type equip work necessari produc accept materi incorpor work',
#  'foot grade shown plan provid contractor work meet templat straightedg requir contain suitabl transit',
#  'obstruct navig channel without permiss proper author provid maintain navig light signal accord feder requir protect structur fals work navig',
#  'credit traine establish number contract carri bank contractor credit allow surplu traine subsequ applic project',
#  'contract claus request made',
#  'claim acceler depart shall liabil construct acceler work shall contractor right make claim construct acceler includ element claim contractor may otherwis submit contract',
#  'sublet work ensur subcontractor worker compens insur employe accord florida worker compens law',
#  'follow applic feder land manag agenc requir state requir',
#  'depart requir bidder prequalifi contractor bid construct contract less construct build',
#  'take measur describ subsect unless otherwis modifi measur subsect section control work perform',
#  'maintain osha form log work relat injuri ill make avail inspect',
#  'failur restor damag exist properti case failur part contractor restor properti bridg road street make good damag injuri engin may upon hour notic proceed repair rebuild otherwis restor properti road street may deem necessari depart deduct cost thereof moni due may becom due contractor contract',
#  'engin sole judg accept propos estim net save construct cost adopt part propos',
#  'object effect effici contract perform achiev qualiti project within budget schedul',
#  'whenev contractor activ damag exist properti immedi restor condit equal better exist time damag occur expens depart',
#  'applic made behalf subcontractor shall consid incomplet subcontract unit price work clearli delin includ submitt',
#  'depart releas propos guaranti except two lowest respons bidder immedi follow open check propos',
#  'increas work depart may grant extens contract time increas contract amount due overrun origin contract item add new work item provid unforeseen work',
#  'test report avail histor materi data furnish contractor upon request',
#  'major item work defin increas excess decreas origin contract quantiti',
#  'author inspector inspector author inspect work includ prepar fabric manufactur materi project',
#  'weigh devic determin indic true mass materi receiv last previous correct weigh accuraci test reduc percentag error excess percent',
#  'review contract document determin submitt requir',
#  'api avail construct offic websit th day month follow url http www',
#  'incorpor contract schedul util work schedul includ contract document unless util compani depart mutual agre chang util schedul shown contract',
#  'contractor shall notic intent claim time file less weekli thereaft long appropri submit contractor daili record engin likewis entitl receiv depart daili record',
#  'total amount bid pay item show total bid amount',
#  'total amount subcontract contract',
#  'depart also acquir modif revis origin',
#  'foot interv locat chang right way width occur',
#  'new design independ peer review shall complianc applic depart fhwa aashto criteria requir includ bridg load rate',
#  'util adjust certain util adjust reconstruct work may underway progress contract',
#  'materi accept certif may sampl test materi determin conform contract materi reject whether place',
#  'accept partner offer contractor option partnership bilater',
#  'depart requir statement depart comptrol fund avail prior enter',
#  'storag area treatment attenu storag area identif number dimens elev contour cross section suffici determin stage storag relationship storag area perman pool depth volum control elev normal wet system',
#  'part contract complementari describ provid complet work',
#  'provid workmen shall make due proper effort execut work manner prescrib contract document engin may take action prescrib',
#  'partial payment made aggreg base cours materi receiv pave base construct oper begin except construct sequenc design depart requir suspens pave base construct initi pave oper partial payment reinstat pave base construct resum',
#  'exclus remedi notwithstand provis contract parti agre depart shall liabil contractor expens cost item damag specif identifi payabl',
#  'upon complet contract transfer cost depart public record possess contractor keep maintain public record requir depart perform servic',
#  'temporari formwork construct affect public safeti major unusu structur prior placement concret ensur specialti engin designe inspect formwork submit written certif engin formwork construct safe withstand superimpos load subject',
#  'adjust payment materi lot made price determin multipli contract unit bid price lot pay factor determin describ payment subsect section order work',
#  'submit inform subcontract lower tier',
#  'complet bridg structur bridg structur element compon compris load carri assembl complet assembl connect final posit',
#  'provid addit space requir expens depart',
#  'protect indemnifi govern repres claim liabil aris base alleg violat',
#  'use spring balanc',
#  'agreement contractor supplier stockpil materi must includ provis supplier store materi materi properti contractor',
#  'develop oper accord approv sourc develop plan govern provid sourc written agreement contractor locat sourc',
#  'work structur navig water',
#  'item list payment lump sum unit plan show estim compon quantiti bidder sole respons estim quantiti',
#  'commerci weigh system use perman instal certifi commerci scale',
#  'specif special provis provid depart determin pay quantiti item basi area finish work adjust accord ratio measur thick nomin thick',
#  'percent contract price pay item',
#  'placement maintain record deliveri document accept manner includ follow applic',
#  'four ten slurri unit contain materi cover one acr hectar measur accord subsect',
#  'pay item provid free cost depart shall indic free',
#  'contractor given option accept reject adjust',
#  'price adjust determin cost accord far part contract cost principl procedur follow requir far claus provid equit price adjust',
#  'depart modif contract document notif modif contract document post depart websit follow url address http www',
#  'work complet identifi measur interim measur',
#  'result deliber act without reason good faith basi specif intend disrupt contractor perform',
#  'partner facilit contract co offer particip formal partnership contractor',
#  'suspens remov equip materi clear zone except requir safeti travel public retain suffici personnel job site properli meet requir section',
#  'sureti furnish legal defens payment perform claim suit sureti shall indemnifi provid defens depart call upon claim suit depart third parti pertain contractor payment perform issu aris contract contractor fail time provid depart defens',
#  'form falsework cast place concret structur greater feet meter height',
#  'movement equip around project site must accord requir standard plan creat undu hazard travel public worker',
#  'coast guard permit condit preced final accept project submit engin certifi survey verifi built clearanc describ us armi corp engin permit',
#  'name person measur work',
#  'quantiti paid exceed correspond quantiti estim contract',
#  'purpos award open read propos depart consid bid correct summat unit bid price multipli estim quantiti shown propos',
#  'comput quantiti use averag end area multipli horizont distanc along centerlin refer line end area',
#  'submit certif engin prior incorpor materi product project',
#  'complet work depart upon declar default depart full author appropri use suitabl accept materi equip site may enter agreement other complet work contract may use method complet work accept manner',
#  'autom machin guidanc util set stake greater feet tangent feet curv',
#  'legal relationship parti perform contract contractor independ contractor',
#  'depart liabil anticip profit unfinish work',
#  'applic condit met approv particip made offic comptrol applic notifi approv action taken',
#  'protect structur oper heavi equip close enough pipe headwal structur caus displac',
#  'equip rate base latest edit date work perform begin rental rate blue book construct equip rental rate blue book older construct equip whichev applic publish machineri inform divis primedia inform inc',
#  'provid addit space need',
#  'govern employe busi organ own substanti own control one govern employe may contractor',
#  'contractor make modif perman work purpos expedit contractor chosen construct method contractor shall submit propos engin record review approv prior modifi work',
#  'insecticid herbicid use product found follow websit http state',
#  'depart accept offici bid set propos form gener depart bid softwar along complet propos packag submit via internet accord',
#  'preconstruct confer immedi award contract contractor begin work engin call preconstruct confer place engin design go construct aspect project',
#  'notifi engin write least two day advanc start date import featur work',
#  'discuss feasibl sequenc futur work mitig delay',
#  'necessari engin may requir contractor first construct work area along project inconveni caus construct oper would present seriou handicap',
#  'florida statut contractor fail complet work within contract time depart may recov contractor amount depart pay damag suffer third parti unless failur time complet work caus depart act omiss',
#  'right collect depart right appli payment liquid damag money depart owe contractor',
#  'ownership dispos exist materi take ownership dispos materi design properti parti roadway structur found right way materi structur design remov',
#  'price adjust made amount gasolin diesel fuel estim depart requir complet contract',
#  'use specif manufactur process process modifi chemic content physic shape size final finish product begin initi melt continu final shape coat',
#  'depart delet util reloc work contract depart recalcul contract bid tabul base remain project quantiti',
#  'pipe culvert box culvert qualifi bridg exclud requir',
#  'depart respons loss suffer due necessari remov repair defect',
#  'fhwa form notic project subject titl crimin code section poster',
#  'bidder propos guaranti bind project includ contract award contractor pursuant provis subarticl',
#  'provid materi contractor certifi invoic maintain requir period',
#  'includ total contract amount cost materi manufactur compon product transport project site',
#  'suppli reason need perform work contractor receiv actual cost suppli',
#  'perform aggreg sourc qualiti test list sampl test accept requir tabl section use govern provid sourc',
#  'howev mandatori submit propos depart accept transmit subcontractor propos propos depart',
#  'internet bid submitt must acknowledg behalf person firm associ corpor submit bid certifi person firm associ corpor either directli indirectli enter agreement particip collus otherwis taken action restraint free competit bid connect submit bid indic propos',
#  'includ quantiti unless field note document quantiti submit close date',
#  'contractor respons work assum respons work final accept except provid subsect',
#  'circuit court arbitr proceed claim part thereof may file final accept per contract work depart denial hereund whichev occur last',
#  'reli avail govern test result process control',
#  'author suspend contractor oper engin author suspend contractor oper wholli part',
#  'waiver contract chang made engin consid waiv provis contract may contractor make claim loss anticip profit chang reason variat approxim quantiti quantiti work actual perform',
#  'govern risk probabl work reject qualiti level accept',
#  'furthermor contractor must submit engin request contract time extens write within day elimin delay control item work identifi preliminari request extens contract time',
#  'submit sampl materi sourc qualiti verif test materi requir conform section',
#  'measur subsect section order work refer anoth section measur work bid schedul contain pay item work referenc section',
#  'document requir signatur must execut electron parti accord chapter florida statut forc effect written signatur',
#  'howev engin determin work thu expos examin accept depart pay',
#  'tangent section set horizont control point foot interv instrument survey',
#  'upon approv engin analysi scope engin specialti',
#  'lot normal repres total quantiti work produc one lot may occur chang target valu materi sourc job mix formula request write approv',
#  'perform qualiti control sampl test accord approv contractor qualiti control plan section applic sampl test accept requir tabl includ end section',
#  'immedi perform remedi work',
#  'upon engin written order perform accept manner necessari repair due open necessari work engin order subject condit origin work perform',
#  'releas retainag accept contractor furnish',
#  'inspect plant work may inspect point product fabric manufactur plant may inspect complianc specifi manufactur method',
#  'protect monument establish perpetu horizont vertic cadastr boundari control necessari destroy monument reestablish monument accord applic state statut direct agenc individu establish monument',
#  'fuel price decreas month bid month',
#  'util work actual affect progress toward complet control work item',
#  'use depart own right way purpos expressli limit storag equip materi project product materi product project',
#  'project number name pay item number descript locat place date load number truck identif time arriv mass volum spread person signatur',
#  'insur describ herein shall maintain final accept work',
#  'contractor discourag transmit volumin submitt shop draw one time',
#  'work around fire hydrant provis continu servic made approv local fire author',
#  'util servic interrupt result damag construct immedi notifi util owner co proper author',
#  'datum north american vertic datum navd nation geodet vertic datum ngvd datum note plan',
#  'method storag store materi manner preserv qualiti fit work facilit prompt inspect minim nois impact sensit receiv',
#  'time certif condit preced right contractor recov compens subcontractor cost failur time submit certif constitut full complet absolut irrevoc waiver contractor right recov subcontractor cost',
#  'submit draw bear seal signatur profession engin profici form falsework design licens state project construct follow',
#  'coordin work caus least impedi overal construct oper util servic',
#  'establish horizont vertic control necessari construct work conform contract document',
#  'contractor shall exert everi reason dilig effort ensur labor employ contractor subcontractor work project work harmoni compat labor use build construct contractor hereaft site work cover contract',
#  'check certif incorpor materi work ensur requir contract met',
#  'feder water pollut control act clean water act usc et seq',
#  'permit commerci area enterpris develop area provid type materi use last year appropri permit',
#  'obtain addit permit agreement modif govern obtain permit agreement requir contractor method oper',
#  'engag servic person person employ depart perform layout work',
#  'one project job separ job number includ contract depart distribut reduc retainag provid first paragraph subarticl separ project job ratio contract valu work particular job bear total contract amount',
#  'written evid previous approv compar defici',
#  'negoti price contract modif work perform submit follow',
#  'engin allow contract adjust differ site condit unless contractor submit requir written notic',
#  'rent equip without oper contractor shall carri oper payrol',
#  'variat qualiti expect feasibl ascertain qualiti materi entir deposit exploratori sampl',
#  'depart pay contractor work either applic contract item accord contract item applic',
#  'particular pay attent chapter rule depart environment protect florida administr code part state implement plan applic project',
#  'contract schedul may indic complet date advanc expir contract time',
#  'unless otherwis specifi measur work place complet accord contract',
#  'monetari compens provid constitut full complet payment addit work contractor shall right addit monetari compens direct indirect cost profit addit work beyond expressli provid',
#  'commenc work contract depart issu notic proceed',
#  'engin reject materi whether place',
#  'contractor receiv prior notic describ reason state subparagraph commit second subsequ act',
#  'specif plan certif complianc requir section accompani final estim',
#  'schedul submitt prepar submit schedul submitt identifi work shop draw appli',
#  'non recover item parti agre claim depart liabil follow item damag expens',
#  'weigh procedur devic batch mass may accept determin pay quantiti approv automat weigh cycl monitor system includ part batch equip',
#  'measur work outsid line slope establish co',
#  'prepar document use unit measur contract plan includ tabl content cover sheet',
#  'materi sourc manag notifi co least day start oper sourc',
#  'submit updat contract schedul engin accept signific chang plan order durat activ',
#  'remov damag limb exist tree approv arborist',
#  'work may elimin contract without invalid contract',
#  'obtain approv prior begin construct platform',
#  'document submit pdf file document trade literatur catalogu inform calcul manual format sheet larger inch inch',
#  'depart requir addit submitt submitt cost save initi propos major modif',
#  'word conting sum fix rate appear unit bid price includ govern insert amount bid pay item total bid amount',
#  'cut otherwis damag materi remov unless engin give permiss',
#  'consecut number sheet submitt seri indic total number seri',
#  'receipt non receipt propos consid ground bid protest',
#  'repay moni advanc program made valu work accomplish particip reach percent',
#  'tabul total quantiti contract price work accomplish complet pay item',
#  'contractor fail remov person person engin may withhold estim may becom due suspend work contractor compli order',
#  'propos submit propos chang design pavement system would requir addit right way',
#  'temporari work construct affect public safeti submit engin record shop draw applic calcul design special erect equip brace falsework scaffold etc',
#  'revis schedul resubmit approv depart district contract complianc manag',
#  'ornament tree shrub take ownership ornament tree shrub exist right way requir remov construct oper specif design plan reset remov other prior construct oper',
#  'case continu delay singl preliminari request extens contract time requir',
#  'depart accept secur certif deposit letter credit replac retainag',
#  'author chang work depart design pay quantiti item lump sum plan show estim quantiti depart adjust compens item proportion author plan chang made result increas decreas quantiti item',
#  'certifi survey must sign seal profession engin profession surveyor mapper regist state florida',
#  'specif provid deduct due test result fall outsid allow specifi toler',
#  'resum oper author engin write',
#  'insert substanc provis claus subcontract issu pursuant contract',
#  'depart determin contractor delinqu depart give contractor written notic intent suspend contractor certif qualif',
#  'accept propos shall describ error defect either describ remedi action',
#  'submit plan pdf file scale contract plan format inch inch sheet',
#  'ensur letter number legibl identif purpos time',
#  'engin request time final accept work remov uncov portion finish work direct',
#  'also submit shop draw detail requir effect prosecut concret work includ contract document special erect equip masonri layout diagram diagram bend reinforc steel addit detail requir concret compon perman work',
#  'project origin contract amount greater within calendar day receipt complet claim submit contractor complianc',
#  'titl sheet built draw bold text name contractor name co site repres project complet date revis project length revis begin end station project revis index sheet revis curv widen tabl strikeout schedul option award note state work construct design unless otherwis note plan note',
#  'depart compens contractor cost associ repair restor exist properti accord',
#  'sack packag materi furnish net weight pack manufactur may use',
#  'design loan mobil payment made payabl jointli prime contractor particip financi institut',
#  'includ work perform close date follow month invoic submit invoic design bill offic',
#  'park privat vehicl outsid clear zone',
#  'prepar shop draw use unit measur use contract plan',
#  'perform qualiti control sampl test accord approv contractor qualiti control plan section applic sampl test accept requir tabl includ end section',
#  'sole cost incur beyond reason mitig thereof contractor could undertaken',
#  'construct toler constru defin revis author templat',
#  'time impact analysi compli applic contract claus request time extens',
#  'termin contract portion thereof provis subarticl reliev contractor sureti respons complet portion contract oblig concern claim aris work perform',
#  'depart submitt requir contract invoic eeo report materi certif certif materi procur etc',
#  'credit allow train posit indic approv job train schedul contractor demonstr good faith effort provid train classif made',
#  'request equit adjust fail fulli compli certif requir review depart',
#  'formwork scaffold temporari work affect public safeti develop requir design accord aashto guid design specif bridg temporari work aashto construct handbook bridg temporari work chapter structur design guidelin sdg use wind load specifi sdg',
#  'internet bid submitt unless otherwis indic advertis bidder shall use depart bid softwar prepar bid internet submitt',
#  'entitl time extens due extra work limit sole provid',
#  'work platform indic permit construct submit work platform construct plan appropri coast guard district approv',
#  'depart consid propos receiv time set open bid',
#  'work moveabl bridg request temporarili chang oper requir moveabl bridg must submit write appropri coast guard district bridg branch day start action',
#  'submit time impact analysi revis construct schedul within day end time impact event notic given includ follow',
#  'qualifi applic depart issu certif fix type work aggreg amount work depart allow prequalifi bidder contract one time',
#  'theft vandal consid damag caus third parti',
#  'govern may inspect sampl test work final accept project',
#  'curv section set horizont control point foot interv locat referenc centerlin exist pavement',
#  'month month defin gregorian calendar measur portion month prorat base total day work',
#  'acquir permit requir aquat plant control outlin chapter florida administr code rule florida depart environment protect',
#  'price adjust base monthli bulk averag price ga diesel deriv depart',
#  'railroad shall also ad along depart addit insur polici i procur pursuant subsect',
#  'provid secur store materi',
#  'discoveri unmark human burial unmark human burial discov immedi ceas activ may disturb unmark human burial notifi engin',
#  'depart may requir manufactur submit sampl materi independ verif purpos',
#  'inform may requir furnish oath failur sureti respond request document within day receipt request caus reject sureti',
#  'arrang light prevent interfer traffic produc undu glare properti owner',
#  'rather author call attent contractor failur work materi meet contract document author reject materi suspend work question issu refer decid engin',
#  'replac excav use accept materi cost govern',
#  'ubmit addit specif draw uniqu situat clarifi layout construct detail method request co',
#  'howev place store discard equip materi rubbish site',
#  'prior use foreign steel iron materi project submit invoic document actual cost materi obtain engin written approv prior incorpor materi project',
#  'engin review correct schedul respond within calendar day receipt',
#  'subarticl appli cost reduct propos hereinaft refer propos contractor initi develop purpos refin contract increas cost effect significantli improv qualiti end result',
#  'provid origin signatur certif facsimil unaccept',
#  'engin give express written direct contractor acceler effort written direct set forth price pertin inform reduc written contract document promptli',
#  'must reason assur stockpil materi incorpor specif project partial payment made',
#  'use privat properti storag without written permiss owner lesse',
#  'obtain insur compani author busi appropri state',
#  'within limit construct project depart allow oper equip haul unit weight caus damag previous construct element project includ necessarili limit bridg drainag structur base cours pavement',
#  'employ discharg person project without written consent engin',
#  'intent contract provid construct complet everi detail work describ contract',
#  'sampl locat exact locat sampl determin co base random number',
#  'control point furnish depart engin provid centerlin control point begin project end project pi pt etc',
#  'begin work notifi engin less five day advanc plan start day work',
#  'propos made limit liabil compani execut propos set compani name manag author member sign propos enter compani bid offic address',
#  'restor govern provid storag site origin condit',
#  'refer mark point necessari provid line grade construct roadway',
#  'shop draw concret structur submit shop draw concret compon cast place otherwis exempt submitt requir',
#  'build structur submit work shop erect draw correspond relat build structur rest area pavilion offic build mainten warehous architect record resid engin review approv',
#  'increas decreas alter shall constitut breach contract shall invalid contract releas sureti liabil aris contract sureti bond',
#  'upon complet work depart accept work make final payment remov right way adjac properti falsework equip surplu discard materi rubbish temporari structur restor accept manner properti public privat damag prosecut work leav waterway unobstruct roadway neat present condit throughout entir length work contract',
#  'includ mileston activ mileston requir contract document',
#  'develop requir brace design accord aashto lrfd bridg design specif lrfd chapter sdg use wind load specifi sdg',
#  'compli applic law ordin safeti code regul order decre',
#  'co may requir inform furnish oath failur sureti accept mail failur sureti respond request inform document within day receipt request caus reject sureti',
#  'coordin contract document',
#  'work measur measur subsect section order work bid schedul contain pay item work section order work',
#  'partial final accept maintain work construct project accept repair damag caus contractor final accept entir project cost govern see far claus use possess prior complet',
#  'includ submitt document catalog data procedur manual fabric weld procedur mainten oper manual requir work',
#  'issuanc notif find due addit review impact requir',
#  'depart recogn subcontractor capac employe agent contractor engin may requir contractor remov subcontractor case employe',
#  'notic base upon reason state subparagraph contractor within period ten calendar day receiv notic describ',
#  'submit avail histor data indic accept materi produc sourc',
#  'payment full extent monetari compens entitl due contractor extra work',
#  'major modif modif opinion engin significantli affect quantiti measur work integr maintain structur compon',
#  'construct contract requir prequalif file applic qualif use depart onlin prequalif applic system give detail inform respect financi resourc equip past record personnel experi',
#  'failur provid notic intent preliminari time extens request time extens request certifi written claim full complet claim document within time requir shall constitut full complet absolut irrevoc waiver contractor right addit compens time extens claim',
#  'depart agricultur florida depart agricultur consum servic issu quarantin regul pertain control nematod citru rule florida administr code plant pest',
#  'measur test conform',
#  'test result submit govern inform allow co opportun wit sampl split test materi',
#  'unauthor discharg occur prevent contamin notifi appropri author co mitig damag',
#  'upon time receipt request contract time extens engin investig condit determin increas time cost perform control item work beyond control contractor adjust contract time made monetari adjust made exclud loss anticip profit contract modifi write accordingli',
#  'repair damag underground util shown plan identifi construct caus fault neglig contractor paid govern',
#  'depart consid effect util reloc adjust work job progress basi grant time extens follow criteria met',
#  'contractor risk either probabl work produc accept qualiti level aql reject probabl work produc aql accept less contract unit bid price',
#  'oper haul unit equip load excess maximum weight specifi',
#  'linear foot meter applic measur work along length end end parallel base foundat along top along front face along invert',
#  'prior approv engin may modifi propos concurr contractor make accept',
#  'restrict appli road bridg insid outsid contract limit long road bridg open public use',
#  'engin use accept schedul baselin measur progress',
#  'contractor origin design submit shop draw applic calcul engin record review',
#  'preconstruct confer held contract award begin work seven day preconstruct confer submit copi preliminari construct schedul accord section',
#  'includ frequenc type verif perform ensur construct grade conform contract document',
#  'take cross section origin ground use design stake templat determin end area',
#  'bond obligor shall materi supplier oblige shall contractor florida depart transport',
#  'special permit reliev contractor liabil damag result move materi equip',
#  'prequalifi contractor bid contract must certifi total dollar amount work underway submit form spreadsheet similar format prior submit bid',
#  'contractor avail opportun train personnel state fund project bank traine hour credit shall compli train criteria set forth section feder aid project voluntari bank may deni depart staff avail monitor complianc train criteria',
#  'contractor submit requir mill test analysi report',
#  'post legal gross vehicular weight display maximum legal gross weight specifi florida uniform traffic code perman manner side dump truck dump type tractor trailer unit haul embank materi construct aggreg road base materi hot bitumin mixtur project public road street',
#  'provid superintend speak understand english maintain least one respons person speak understand english project work hour',
#  'engin may inspect test materi point product distribut use',
#  'procur maintain railroad protect liabil coverag iso form cg railroad name insur limit less combin singl limit',
#  'full author receiv instruct engin execut order direct engin includ promptli suppli materi tool equip labor incident may requir',
#  'measur structur line accord plan approv line adjust fit field condit',
#  'manufactur requir submit request depart approv modif alter made product list apl',
#  'lot contain unsatisfactori percentag non specif materi less pay factor accept provid lowest singl pay factor fallen reject portion tabl',
#  'upon request submit depart copi subcontract agreement',
#  'requir remov materi restor land satisfactori condit cost govern',
#  'bridg notifi appropri coast guard district bridg branch least day prior start oper includ construct day prior channel oper closur open restrict',
#  'cross railroad track vehicl equip except exist open public grade cross railroad approv temporari grade cross',
#  'resubmiss propos withdrawn must made complet propos subject provis',
#  'contract far claus limit subcontract appli percentag work perform contractor comput cost contract work perform contractor employe includ cost materi divid cost contract work includ cost materi',
#  'date place manufactur',
#  'direct cost includ document invoic support direct cost incur includ bond mobil demobil permit royalti',
#  'depart labor manpow administr bureau apprenticeship train shall also consid accept provid administ manner consist equal employ oblig feder aid highway construct contract',
#  'contract time extens depart may grant extens contract time control item work delay factor reason anticip forese time bid',
#  'perform work line grade cross section dimens process materi requir shown contract',
#  'depart oblig pay reimburs damag caus',
#  'govern respons cost attribut repair replac damag work caus declar enemi terrorist govern cataclysm natur phenomenon',
#  'perform work cover supplement agreement unilater payment written author receiv engin',
#  'shape dress area adjac project right way use plant site materi storag area equip yard longer need purpos',
#  'oper vehicl equip safe without hindranc travel public',
#  'fertil ensur employe appli fertil possess current florida depart agricultur consum servic commerci applic licens accord section',
#  'period suspens contractor certif qualif depart allow contractor affili bid depart',
#  'represent may label catalog data stamp specif standard supplier certif indic materi produc commerci standard specif',
#  'close date invoic submitt date close date progress payment design co',
#  'built draw certifi survey must sign seal appropri licens profession regist state florida',
#  'upon satisfactori complet work depart submit written notic accept either partial final contractor',
#  'preserv public privat properti',
#  'meet co jointli review built draw log accuraci complet legibl submiss monthli invoic',
#  'contractor entitl compens direct cost incur date elimin work plu profit overhead direct incur cost anticip profit overhead expens elimin work compens',
#  'qualiti materi gener accept',
#  'depart right default contractor affili convict contract crime shall extend expressli applic depart contract either advertis bid request propos letter interest request intent award post otherwis issu contract enter date underli relat crimin indict crimin inform crimin charg file contractor affili result convict',
#  'sureti contract bond consent complet portion affidavit sureti releas subsequ contractor complet portion final payment contractor agre make payment reliev sureti oblig bond',
#  'submit depart approv design calcul layout draw erect draw show equip use bridg structur overstress',
#  'built draw certifi survey must pdf file scale contract plan format inch inch sheet satisfi requir special condit list water manag district environment resourc permit erp applic local permit',
#  'event depart delet util reloc work contract util owner reloc util accord backup util reloc schedul contain contract document',
#  'use prevail industri standard absenc contract requir toler',
#  'condit preced final accept project submit engin built draw certifi survey verifi built condit',
#  'solicit price quotat arrang time review plan quantiti specif deliveri schedul prepar present quotat',
#  'train permiss lower level manag posit offic engin estim etc',
#  'approxim locat temporari falsework conceptu outlin special erect equip',
#  'contractor record upon request provid record relat contract govern year final payment longer period provid law',
#  'invoic bulk materi ship truck rail pass mix plant submit supplier invoic net mass volum convert mass',
#  'incorpor materi requir submitt work approv',
#  'document complianc applic law regul',
#  'depart includ allow delay caus effect inclement weather suspens contractor oper defin',
#  'credit allow traine previous enrol depart approv train program anoth contract continu train job classif complet train differ contract',
#  'dust control control dust storag handl dusti materi wet cover mean approv engin',
#  'perform eros sediment control accord sourc develop plan storm water pollut prevent plan swppp eros control plan',
#  'construct aggreg aggreg use depart project must accord rule fac',
#  'immedi notifi engin write result coordin appropri resourc agenc',
#  'post permit placard protect locat worksit',
#  'depart execut contract within calendar day exclud saturday sunday state holiday receipt sign contract necessari agreement contract bond requir document contractor',
#  'submit evid corpor person sign author bind corpor',
#  'final accept notifi co entir project complet schedul inspect',
#  'understood matter individu act sole agent repres depart',
#  'depart open publicli announc propos time place indic advertis',
#  'gener construct materi use construct project except materi exempt',
#  'journal base rate corpor loan post least nation largest bank th calendar day follow depart receipt certifi written claim full complianc',
#  'coupl vehicl may weigh separ togeth accord subsect paragraph ur singl draft vehicl weigh nist handbook specif toler technic requir weigh measur devic',
#  'asphalt materi ship truck transport net certifi mass subject correct loss foam may use comput quantiti',
#  'asphalt plant oper maintain asphalt plant accord chapter rule depart environment protect florida administr',
#  'failur submit sign notif submit claim document within time frame specifi may result suspens contractor certif qualif provis florida administr code',
#  'progress payment follow requir far claus payment fix price construct contract far claus prompt payment construct contract',
#  'coordin review date stamp approv sign shop draw prepar contractor agent subcontractor fabric supplier etc',
#  'weigh pay quantiti program printer provid follow inform weigh',
#  'acr hectar squar feet squar meter',
#  'store explos secur manner complianc law ordin clearli mark storag place word danger explos',
#  'whenev action third parti damag exist properti otherwis due fault activ contractor either restor condit equal better exist time damag occur provid access coordin depart mainten contractor accord',
# ...
#  'identif whether measur interim final',
#  'contractor shall ten calendar day receipt notic resubmit claim document without chang certif claim describ',
#  'contractor paid bill suit pend except list connect work perform contract contractor offer made gift gratuiti made financi transact natur employe depart perform contract',
#  'coverag shall occurr basi shall includ product complet oper coverag',
#  'perform final ground survey measur accord subsect',
#  'take advantag appar error omiss discov contract document immedi notifi engin write discoveri',
#  'remov replac work conform contract prevail industri standard specif contract requir note cost govern',
#  'govern respons delay cost impact cost extend overhead cost',
#  'depart may reject improperli store materi',
#  'increas sampl frequenc may result reduc pay factor',
#  'contractor fail submit requir request contract time extens without detail cost analysi depriv engin time opportun verifi delay cost delay contractor waiv entitl extens contract time addit compens delay',
#  'partial payment materi constitut accept materi use complet item work partial payment made live perish materi incorpor project',
#  'falsework structur traffic worker involv construct structur travel structur temporari bridg structur public use',
#  'shop draw distribut approv stamp valid work contractor perform advanc approv contractor risk',
#  'multipl job contract chang made individu pay item due substanti error base entir contract quantiti pay item',
#  'mse tie back wall detail altern retain wall detail detail instal procedur proprietari wall system',
#  'depart immedi releas propos guaranti two lowest respons bidder success bidder deliv execut contract satisfactori contract bond depart except depart retain propos guaranti next lowest respons bidder longer day open propos unless depart award contract next lowest respons bidder prior expir time limit',
#  'non duplic payment case basi payment claus specif relat unit price bid schedul requir unit price cover consid compens certain work materi essenti item depart measur pay work materi pay item may appear elsewher specif',
#  'submit propos understand success bidder shall furnish contract bond pursuant requir',
#  'depart labor wage hour divis whd whd employe right davi bacon act poster regard proper pay',
#  'contractor shall submit district contract complianc manag copi job train notif personnel action form later seven day effect date action follow action occur traine transfer project transfer project continu train anoth contract complet train upgrad journeyman statu voluntari termin involuntari termin project',
#  'subcontractor depart encourag contractor includ provis subarticl contract subcontractor encourag submiss propos subcontractor',
#  'use product sulfonylurea famili chemic',
#  'necessari connect exist walk drive indic plan engin submit direct regard proper connect accord standard plan',
#  'depart labor osha job health safeti law poster accord titl code feder regul part',
#  'failur complet work time follow requir far claus liquid damag construct',
#  'digit id repres firm individu partnership corpor limit liabil compani joint ventur',
#  'preliminari request extens contract time must oper schedul util work preconstruct confer provid adequ advanc notif util compani date coordin oper contractor oper avoid delay submit write engin within ten calendar day commenc delay control item work',
#  'worker compens insur minimum requir law',
#  'mark certif follow inform project number name pay item number descript contractor signatur date',
#  'independ peer review intend comprehens thorough verif origin work give assur design complianc depart requir',
#  'time extens delay modif affect critic activ caus noncrit activ becom critic consid time extens',
#  'extent contractor could reason mitig idl',
#  'unless otherwis shown plan depart own underground facil locat depart notif sunshin',
#  'howev engin determin necessari extend construct order make suitabl connect exist pavement engin author chang write',
#  'shop draw shall submit portabl document format pdf file format inch inch sheet',
#  'engin may requir contractor finish section work progress start work addit section',
#  'event legal action addit compens whether account delay acceler breach contract otherwis contractor agre depart liabil limit item specif identifi payabl',
#  'contractor shall indemnifi provid defens depart call upon claim suit depart third parti pertain contractor payment perform issu aris contract',
#  'adjust propos total payment relat quantiti qualiti pay item',
#  'outlin handl transport storag fabric compon girder concret segment',
#  'document submit without evid contractor approv may return resubmiss',
#  'depart consid request time extens due delay deliveri custom manufactur equip traffic signal equip highway light equip etc',
#  'furnish right way govern obtain right way',
#  'detail specif concern storag specif materi prescrib applic specif',
#  'condit preced contractor right grant extens contract time monetari compens aris delay',
#  'partial accept engin sole discret engin may accept portion work provis',
#  'direct cost partner facil profession facilit copi fee miscellan cost directli relat partner meet share contractor govern',
#  'contractor sole respons util impact cost delay damag whether direct indirect result contractor initi chang design construct activ origin contract specif design plan includ traffic control plan contract document effect chang util work differ shown util plan joint project agreement util reloc schedul',
#  'certif payment subcontractor term subcontractor use herein includ person firm furnish materi equip incorpor work stockpil depart made partial payment firm work equip rental agreement satisfactori perform contract depart make progress partial payment',
#  'design liaison offic within contractor organ well support staff necessari proper administ program descript author respons duti liaison offic support staff',
#  'addit co may review sf documentari inform secur interest asset pledg request sureti submit inform document respect document submit',
#  'begin work area contact local util locat servic mark util protect util construct oper',
#  'upon execut contract depart reserv right conduct audit contractor record pertain project',
#  'worker compens insur provid worker compens insur accord florida worker compens law employe',
#  'crack element provid draw show locat averag width depth length termin point crack along surfac',
#  'submit copi current certif engin upon request',
#  'written notif submit engin afford opportun keep strict account actual labor materi equip time contractor waiv claim addit compens time extens',
#  'watchman flag servic railroad compani furnish protect servic',
#  'addit compens made delay caus deliveri materi compon equip',
#  'execut agreement sublet work write includ pertin provis requir contract',
#  'contain structur bridg work girder erect plan',
#  'failur depart fulfil oblig contract result delay control item work depart consid delay basi grant time extens contract',
#  'depart held respons bidder can not complet submit revis bid due failur incomplet deliveri file submit via internet',
#  'layout work util control point furnish depart accord',
#  'certif claim submit claim contractor shall certifi oath write accord formal requir florida law claim made good faith support data accur complet contractor best knowledg belief amount claim accur reflect contractor good faith believ depart liabil',
#  'execut time impact analysi incorpor accept logic chang time extens baselin schedul next monthli submitt',
#  'determin appropri depart sole judgment',
#  'commerci certif manufactur contractor represent materi compli contract',
#  'limit coverag shall less occurr less annual gener',
#  'insur coverag minimum amount set forth reliev contractor liabil excess coverag',
#  'light may accomplish use portabl floodlight standard equip light exist street light temporari street light light method approv engin',
#  'contractor use subcontractor qualifi nonprofit agenc blind sever handicap section',
#  'ensur insur cover oper contract whether perform contractor subcontractor',
#  'alert presenc tank barrel discolor stain earth metal wood ground water visibl fume abnorm odor excess hot earth smoke condit appear abnorm possibl indic presenc contamin materi',
#  'depart agricultur divis plant industri florida depart agricultur consum servic ascertain current restrict regard plant pest impos agenc',
#  'contract amount defin origin contract amount adjust approv supplement agreement',
#  'indic shop draw deviat contract draw item deviat letter transmitt',
#  'submitt review duli certifi request equit adjust shall neither creat modifi activ legal right oblig contractor depart depart review content duli certifi request equit adjust disput resolut propos action inact depart thereaft sole discret',
#  'gallon gallon measur accord subsect',
#  'right use process materi found work exclud use process materi nongovern contract work except dispos wast materi',
#  'gener invoic payment made contract',
#  'notif letter detail chang made result review stipul action taken depart requir contractor',
#  'offsit train permiss long train integr part approv train program compromis signific part overal train',
#  'qualiti characterist evalu sampl frequenc sampl locat test method categori list accept subsect section follow appli',
#  'ensur certif includ contract number financi project identif fpid number certif date number period certif repres ton produc asphalt pay item',
#  'submit certif manufactur steel iron product contain steel iron state steel iron furnish incorpor furnish product produc manufactur unit state statement product produc within unit state except minim quantiti foreign steel iron valu actual cost',
#  'depart may allow extens time delay occur contract time period author extens contract time period',
#  'within day subcontract award submit sf statement acknowledg part complet',
#  'use materi reject engin approv materi use',
#  'default contractor case default part contractor depart charg contract bond expens servic incident ascertain collect loss contract bond includ account engin legal servic togeth cost incur connect renegoti contract',
#  'period check weigh may requir',
#  'contractor fail compli contract document',
#  'product project reloc least per year weigh portion system check certifi state bureau weight measur privat scale servic certifi bureau weight measur seal system prevent tamper adjust certif',
#  'worksheet use prepar claim establish cost compon item claim includ limit labor benefit insur materi equip subcontractor document establish time period individu involv hour rate individu',
#  'contractor fact engin kept account labor materi equip time shall way constru establish valid claim method',
#  'pay item left blank use bid may declar irregular',
#  'util privat own unit state flag commerci vessel ship least percent gross tonnag comput separ dri bulk carrier dri cargo liner tanker involv whenev ship equip materi commod pursuant contract extent vessel avail fair reason rate unit state flag commerci vessel',
#  'maximum obtain pay factor sampl least sampl requir obtain pay factor',
#  'depart reserv right cancel award contract time execut contract parti compens due bidder',
#  'averag index shall determin averag bulk fuel price first day month quot major oil compani reason expect furnish fuel project state florida',
#  'depart may award contract next lowest respons bidder advertis accomplish work use altern resourc',
#  'continu accept sureti provid contract bond remain accept depart throughout life contract',
#  'evid guarante assist sureti guarante assist small busi administr sba shall submit copi sba form sureti bond guarante agreement sf',
#  'approv obtain notic proceed issu disburs moni made request applic',
#  'minimum length type train classif establish post preconstruct traine evalu meet approv depart',
#  'depart may deduct payment estim sum contractor owe depart account',
#  'number traine may distribut among work classif basi contractor need avail journeymen variou classif within reason area recruit',
#  'internet bid submitt unless otherwis indic advertis propos may submit via internet',
#  'furnish compet scale oper oper system',
#  'advertis state locat descript work perform estim variou quantiti applic pay item work perform applic contract time amount propos guaranti date time place open propos',
#  'engin record review shop draw includ mean method techniqu sequenc construct procedur limit effect perman work',
#  'api capi vari api prevail month bid receiv bapi portion exce',
#  'depart requir work cover price contract work constitut signific chang defin',
#  'contractor respons loss damag result equip oper structur perman close public',
#  'invoic requir submit invoic govern design bill offic follow item invoic',
#  'cubic yard cubic meter place measur solid volum method approv co averag end area method follow',
#  'final built draw approv submit final set built draw singl file electron color copi draw',
#  'method measur engin take measur horizont vertic',
#  'notifi co util work requir',
#  'howev depart may waiv amount subcontract',
#  'govern receiv report',
#  'pay particular attent call safeti regul promulg',
#  'differ site condit progress work subsurfac latent physic condit encount site differ materi indic contract unknown physic condit unusu natur differ materi ordinarili encount gener recogn inher work provid contract encount site parti discov condit shall promptli notifi parti write specif differ condit contractor disturb condit perform affect work',
#  'co may adjust partial payment necessari protect govern',
#  'includ map control point use site calibr control point use valid site calibr',
#  'event depart investig determin potenti impact protect threaten endang speci mitig measur permit necessari coordin appropri resourc agenc clearanc obtain permit perform mitig measur necessari',
#  'prevent introduct noxiou weed non nativ plant speci work site',
#  'use contractor select noncommerci area submit follow',
#  'work price work perform profit limit percent total cost',
#  'place storag care compet watchman',
#  'includ part submitt sign seal calcul detail falsework brace connect support structur element shown erect plan',
#  'order individu structur built sequenc individu span girder cantilev erect sequenc span made continu',
#  'updat resubmit plan everi three year',
#  'asphalt binder asphalt concret pavement store tank devot exclus project valid quantiti request payment question base quantiti asphalt content determin test',
#  'investig condit encount charact qualiti quantiti work perform materi furnish requir contract document',
#  'withhold payment failur compli depart withhold progress payment contractor fail compli follow within day begin work',
#  'requir includ time extens request propos chang compar advantag disadvantag',
#  'schedul work affect railroad oper minim need protect servic railroad compani',
#  'discharg structur structur identif number type locat latitud longitud dimens elev includ weir bleeder orific gate pump pipe oil greas skimmer',
#  'agent agent sign state subsect furnish satisfactori evid agent author bind bidder',
#  'use equip leak fluid repair equip fluid leak immedi',
#  'whenev use design devic materi process cover letter patent copyright obtain right use suitabl legal agreement patente owner copyright',
#  'contractor author subcontractor appli roof materi must licens approv dealer applic propos roof materi',
#  'item encount suspend oper discoveri site notifi co continu oper area',
#  'bid guarante follow requir far claus bid guarante',
#  'maintain scale accuraci within percent correct mass throughout rang use',
#  'submiss time notic intent file claim preliminari time extens request time extens request certifi written claim togeth full complet claim document condit preced contractor bring circuit court arbitr formal claim resolut proceed depart item',
#  'engin use method combin method measur reflect reason accuraci actual surfac area finish work engin determin',
#  ...]

# %% [markdown]
# ### 2. CounterVectorize를 활용한 벡터화

# %%
from sklearn.feature_extraction.text import CountVectorizer

cvector = CountVectorizer(analyzer="word", max_features=1000)
train_x = cvector.fit_transform(clauses)


print(train_x)
# Out:
#   (0, 796)	1
#   (0, 231)	1
#   (0, 113)	1
#   (0, 802)	1
#   (0, 195)	1
#   (0, 267)	1
#   (0, 787)	1
#   (0, 809)	1
#   (0, 800)	1
#   (0, 720)	2
#   (0, 288)	1
#   (0, 182)	1
#   (1, 746)	1
#   (1, 541)	1
#   (2, 789)	1
#   (2, 863)	1
#   (2, 4)	1
#   (2, 417)	1
#   (2, 751)	1
#   (2, 521)	1
#   (2, 128)	2
#   (2, 688)	2
#   (3, 246)	1
#   (3, 519)	1
#   (3, 295)	1
#   :	:
#   (1656, 55)	1
#   (1656, 704)	1
#   (1656, 139)	1
#   (1656, 153)	1
#   (1656, 181)	1
#   (1656, 991)	1
#   (1657, 666)	1
#   (1657, 76)	1
#   (1657, 305)	1
#   (1657, 358)	1
#   (1657, 241)	1
#   (1657, 500)	1
#   (1657, 497)	1
#   (1657, 237)	1
#   (1657, 704)	1
#   (1658, 549)	1
#   (1658, 973)	1
#   (1658, 925)	1
#   (1658, 829)	1
#   (1658, 149)	1
#   (1658, 522)	1
#   (1658, 950)	1
#   (1658, 516)	2
#   (1658, 360)	1
#   (1658, 406)	1

# %% [markdown]
# ### 3. 훈련데이터와 검증데이터 나누기
# 전체 훈련데이터에 사용되는 문장 4049개를 t_size 비율만큼 훈련:검증 데이터로 나눈다. sklearn의 train_test_split 함수를 사용해서 자동으로 분할한다.

# %%
from sklearn.model_selection import train_test_split

t_size=0.2 
r_seed=42

train_cl, eval_cl, train_lb, eval_lb = train_test_split(train_x, train_label, test_size=t_size, random_state=r_seed )

# %% [markdown]
# ### 4. Logistic Regression
#
# - logistic regression 회귀 분석은 sklearn의 linear_model 라이브러리에서 제공한다.
# - .fit() 함수로 훈련 데이터를 주입해 훈련시키고, .score() 함수로 테스트 데이터를 넣어 정확도를 측정할 수 있다.

# %%
from sklearn.linear_model import LogisticRegression

log = LogisticRegression()
log.fit(train_cl, train_lb)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
print("Accuracy of training: %f" % log.score(train_cl, train_lb))
print("Accuracy: %f" % log.score(eval_cl, eval_lb))
# Out:
# Accuracy of training: 0.996986
# Accuracy: 0.915663

# %% [markdown]
# ### 5. 테스트 하기
#
# - 테스트 데이터로 테스트하기
# - 테스트 데이터도 countervectorize로 벡터화하기

# %%
test_data= pd.read_csv('test_data.csv')

test_x = cvector.transform(test_data['clauses']).toarray()
test_y = test_data['label']

# %%
# 예측값 result 구하기
result = log.predict(test_x)

from sklearn import metrics


print("------------")
print("Accuracy: %f" % log.score(test_x, test_data['label']))  # checking the accuracy
print("Precision: %f" % metrics.precision_score(test_data['label'], result))  # checking for the precision
print("Recall: %f" % metrics.recall_score(test_data['label'], result))  # checking for the recall
print("F1-Score: %f" % metrics.f1_score(test_data['label'], result))  # checking for the F-1 score
# Out:
# ------------
# Accuracy: 0.874396
# Precision: 0.925581
# Recall: 0.846809
# F1-Score: 0.884444

# %%
output = pd.DataFrame( data={"label":test_y,  "predict": result} )

output.to_csv("cvec-predict-test.csv", index=False, quoting=3)
