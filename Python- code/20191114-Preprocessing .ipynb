# %%
import re
import pandas as pd
import numpy as np 
import json
from nltk.corpus import stopwords
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from tensorflow.python.keras.preprocessing.text import Tokenizer 


dataInPath='./data_in/'
dataOutPath='./data_out/'
inputFile ='1114-4058.csv'
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
input_text= pd.read_csv(dataInPath+inputFile)
input_text.head()
# Out:
#                                              Clauses  label
# 0  (c) Forms and falsework for cast-in-place non-...      1
# 1  For longspan structures:(a) Tighten the longit...      0
# 2  (1) Format. Prepare a construction schedule di...      1
# 3  Record the following settings and notify the C...      1
# 4  Installed ground anchors will be evaluated bas...      1

# %%
input_text['Clauses'][0]
# Out:
# '(c) Forms and falsework for cast-in-place non-bridge concrete structures and retaining walls less than or equal to 6 feet (1.8 meters) in height; (d) Fabrication drawings for bridge railings and parapets; (e) Fabrication drawings for prestressed members; (f) Fabrication and installation drawings for expansion joint assemblies; (g) Fabrication drawings for bearing assemblies; (h) Construction joint location and concrete deck placement sequences not according to the plans; (i) Erection diagrams for Soil-Corrugated Metal Structure interaction systems (multi-plate structures); (j) Structural steel fabrication drawings; (k) Utility hangar details; (l) Fabrication and installation drawings for precast items; and (m) Site-specific layouts for rockeries.'

# %%
#전처리 함수 
def preprocessing(clauses, remove_stopwords = False):
    cleansing = re.sub("[^a-zA-Z]", " ", clause)
    clean_clauses = re.sub('[^\w\s]','', cleansing)
    net_words = clean_clauses.lower().split()
     
    if remove_stopwords:
        stops = set(stopwords.words('english'))
        net_words = [w.strip() for w in net_words if not w in stops]
        #print(net_words, len(net_words))
        for word in net_words:
            if len(word)<2:
                net_words.remove(word)
        clean_clauses = ' '.join(net_words)
        
    else:
        clean_clauses = ' '.join(net_words)
    
    return clean_clauses

# %%
#전체 데이터에 적용 
clean_input=[]
for clause in input_text['Clauses']:
    clean_input.append(preprocessing(clause, remove_stopwords = True))

# %%
clean_input[0]
# Out:
# 'forms falsework cast place non bridge concrete structures retaining walls less equal feet meters height fabrication drawings bridge railings parapets fabrication drawings prestressed members fabrication installation drawings expansion joint assemblies fabrication drawings bearing assemblies construction joint location concrete deck placement sequences according plans erection diagrams soil corrugated metal structure interaction systems multi plate structures structural steel fabrication drawings utility hangar details fabrication installation drawings precast items site specific layouts rockeries'

# %%
#전처리된 트레이닝 데이터를 판다스 데이터프레임에 저장 
clean_input_df = pd.DataFrame({'clauses':clean_input, 'label':input_text['label']})
clean_input_df.head()
# Out:
#                                              clauses  label
# 0  forms falsework cast place non bridge concrete...      1
# 1  longspan structures tighten longitudinal seams...      0
# 2  format prepare construction schedule diagram s...      1
# 3  record following settings notify co water pres...      1
# 4  installed ground anchors evaluated based one f...      1

# %%
print('total traing data set is: {}'.format(len(clean_input_df)))
# Out:
# total traing data set is: 4057

# %%
train_len = clean_input_df['clauses'].astype(str).apply(len)
train_len.head()
# Out:
# 0    603
# 1    545
# 2    574
# 3    585
# 4    511
# Name: clauses, dtype: int64

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
# %matplotlib inline

#히스토그램 그리기 
plt.figure(figsize=(12,5))

plt.hist(train_len, bins=200, alpha=0.5, color='r', label='word')
plt.yscale('log', nonposy='clip')

plt.title('Log-Histogram of len of statement')

plt.xlabel('Len of statement')
plt.ylabel('num of statement ')
# Out:
# Text(0,0.5,'num of statement ')

# %%
#통계분석 
print('max of review len: {}'.format(np.max(train_len)))
print('min of review len: {}'.format(np.min(train_len)))
print('mean of review len: {:.2f}'.format(np.mean(train_len)))
print('std of review len: {:.2f}'.format(np.std(train_len)))
print('median of review len: {}'.format(np.median(train_len)))

print('25 percentile of review len: {}'.format(np.percentile(train_len,25)))
print('75 percentile of review len: {}'.format(np.percentile(train_len,75)))
# Out:
# max of review len: 603
# min of review len: 55
# mean of review len: 175.77
# std of review len: 90.72
# median of review len: 152.0
# 25 percentile of review len: 106.0
# 75 percentile of review len: 219.0

# %%
#데이터 패딩
tokenizer = Tokenizer()  #텐서플로우의 전처리 모듈 사용 
tokenizer.fit_on_texts(clean_input)
text_sequences = tokenizer.texts_to_sequences(clean_input)
print(text_sequences[10])  #전처리된 단어들이 모두 데이터프레임 인덱스의 벡터로 구성됨
# Out:
# [175, 533, 50, 839, 349, 1575, 57, 35, 631, 840, 939, 1399, 47, 145, 160, 1400, 5, 483, 3679, 1804, 2386, 1575, 57, 35, 683, 1695, 4677, 47, 145, 160, 1400, 5, 483, 3679, 1804, 839, 1575, 57, 35, 35, 25, 939, 401, 189, 47, 145, 160, 1400, 5, 13, 1575, 57, 35, 47, 145, 160, 10, 5, 13, 91, 57, 35, 83, 47, 349, 91, 57, 35, 83, 47]

# %%
#단어와 인덱스 사전 확인 
word_vocab = tokenizer.word_index 
word_vocab
# Out:
# {'concrete': 1,
#  'material': 2,
#  'according': 3,
#  'use': 4,
#  'millimeters': 5,
#  'surface': 6,
#  'work': 7,
#  'subsection': 8,
#  'inch': 9,
#  'inches': 10,
#  'furnish': 11,
#  'least': 12,
#  'steel': 13,
#  'place': 14,
#  'asphalt': 15,
#  'construction': 16,
#  'percent': 17,
#  'approved': 18,
#  'provide': 19,
#  'aashto': 20,
#  'following': 21,
#  'control': 22,
#  'within': 23,
#  'section': 24,
#  'type': 25,
#  'required': 26,
#  'test': 27,
#  'water': 28,
#  'co': 29,
#  'aggregate': 30,
#  'per': 31,
#  'remove': 32,
#  'pavement': 33,
#  'equipment': 34,
#  'astm': 35,
#  'mix': 36,
#  'submit': 37,
#  'joints': 38,
#  'days': 39,
#  'grout': 40,
#  'may': 41,
#  'design': 42,
#  'conforming': 43,
#  'specified': 44,
#  'square': 45,
#  'rock': 46,
#  'minimum': 47,
#  'used': 48,
#  'contract': 49,
#  'length': 50,
#  'apply': 51,
#  'using': 52,
#  'load': 53,
#  'joint': 54,
#  'holes': 55,
#  'manufacturer': 56,
#  'conform': 57,
#  'feet': 58,
#  'millimeter': 59,
#  'production': 60,
#  'testing': 61,
#  'strength': 62,
#  'ground': 63,
#  'areas': 64,
#  'end': 65,
#  'one': 66,
#  'maximum': 67,
#  'measure': 68,
#  'grade': 69,
#  'meters': 70,
#  'meter': 71,
#  'surfaces': 72,
#  'soil': 73,
#  'evaluated': 74,
#  'table': 75,
#  'project': 76,
#  'method': 77,
#  'traffic': 78,
#  'less': 79,
#  'time': 80,
#  'contractor': 81,
#  'construct': 82,
#  'schedule': 83,
#  'placement': 84,
#  'placing': 85,
#  'pay': 86,
#  'requirements': 87,
#  'pile': 88,
#  'piles': 89,
#  'hole': 90,
#  'pipe': 91,
#  'depth': 92,
#  'include': 93,
#  'methods': 94,
#  'subsections': 95,
#  'backfill': 96,
#  'temporary': 97,
#  'finish': 98,
#  'pressure': 99,
#  'wire': 100,
#  'top': 101,
#  'final': 102,
#  'hours': 103,
#  'structure': 104,
#  'approval': 105,
#  'including': 106,
#  'face': 107,
#  'line': 108,
#  'area': 109,
#  'shown': 110,
#  'set': 111,
#  'temperature': 112,
#  'content': 113,
#  'slope': 114,
#  'clean': 115,
#  'without': 116,
#  'maintain': 117,
#  'air': 118,
#  'reinforcing': 119,
#  'form': 120,
#  'operations': 121,
#  'structures': 122,
#  'allow': 123,
#  'quality': 124,
#  'cement': 125,
#  'acceptance': 126,
#  'blast': 127,
#  'installation': 128,
#  'sections': 129,
#  'pounds': 130,
#  'anchor': 131,
#  'existing': 132,
#  'size': 133,
#  'mass': 134,
#  'diameter': 135,
#  'application': 136,
#  'make': 137,
#  'structural': 138,
#  'excavation': 139,
#  'paint': 140,
#  'necessary': 141,
#  'compact': 142,
#  'complete': 143,
#  'cut': 144,
#  'wall': 145,
#  'mixture': 146,
#  'mixing': 147,
#  'prevent': 148,
#  'dry': 149,
#  'bolts': 150,
#  'full': 151,
#  'drill': 152,
#  'bearing': 153,
#  'adjacent': 154,
#  'install': 155,
#  'posts': 156,
#  'number': 157,
#  'applicable': 158,
#  'results': 159,
#  'thickness': 160,
#  'designated': 161,
#  'location': 162,
#  'placed': 163,
#  'foot': 164,
#  'width': 165,
#  'government': 166,
#  'c': 167,
#  'mortar': 168,
#  'forms': 169,
#  'perform': 170,
#  'system': 171,
#  'uniform': 172,
#  'layer': 173,
#  'geotextile': 174,
#  'free': 175,
#  'damage': 176,
#  'two': 177,
#  'data': 178,
#  'seal': 179,
#  'shaft': 180,
#  'plan': 181,
#  'proposed': 182,
#  'devices': 183,
#  'limits': 184,
#  'except': 185,
#  'strip': 186,
#  'moisture': 187,
#  'vertical': 188,
#  'density': 189,
#  'plant': 190,
#  'bridge': 191,
#  'members': 192,
#  'rate': 193,
#  'fill': 194,
#  'produce': 195,
#  'exceed': 196,
#  'reinforcement': 197,
#  'site': 198,
#  'drawings': 199,
#  'plans': 200,
#  'drilling': 201,
#  'limit': 202,
#  'class': 203,
#  'tendon': 204,
#  'consists': 205,
#  'metal': 206,
#  'ensure': 207,
#  'gradation': 208,
#  'blasting': 209,
#  'date': 210,
#  'along': 211,
#  'base': 212,
#  'acceptable': 213,
#  'determine': 214,
#  'repair': 215,
#  'additional': 216,
#  'horizontal': 217,
#  'capable': 218,
#  'replace': 219,
#  'exposed': 220,
#  'new': 221,
#  'roadway': 222,
#  'certification': 223,
#  'curing': 224,
#  'payment': 225,
#  'procedures': 226,
#  'tests': 227,
#  'cubic': 228,
#  'general': 229,
#  'continuous': 230,
#  'compressive': 231,
#  'bars': 232,
#  'post': 233,
#  'completed': 234,
#  'total': 235,
#  'color': 236,
#  'quantity': 237,
#  'masonry': 238,
#  'protect': 239,
#  'gauge': 240,
#  'sufficient': 241,
#  'cross': 242,
#  'greater': 243,
#  'specification': 244,
#  'course': 245,
#  'determined': 246,
#  'individual': 247,
#  'factor': 248,
#  'measuring': 249,
#  'compaction': 250,
#  'elevation': 251,
#  'panels': 252,
#  'recommendations': 253,
#  'day': 254,
#  'fabric': 255,
#  'emulsified': 256,
#  'damaged': 257,
#  'plate': 258,
#  'support': 259,
#  'bond': 260,
#  'stone': 261,
#  'inspection': 262,
#  'shotcrete': 263,
#  'centerline': 264,
#  'foundation': 265,
#  'name': 266,
#  'fabricate': 267,
#  'field': 268,
#  'finishing': 269,
#  'excess': 270,
#  'immediately': 271,
#  'precast': 272,
#  'cover': 273,
#  'binder': 274,
#  'made': 275,
#  'prestressing': 276,
#  'value': 277,
#  'slurry': 278,
#  'beginning': 279,
#  'fence': 280,
#  'erosion': 281,
#  'unless': 282,
#  'first': 283,
#  'bolt': 284,
#  'removal': 285,
#  'bottom': 286,
#  'timber': 287,
#  'coat': 288,
#  'capacity': 289,
#  'edge': 290,
#  'flow': 291,
#  'items': 292,
#  'plates': 293,
#  'embankment': 294,
#  'provided': 295,
#  'loose': 296,
#  'values': 297,
#  'initial': 298,
#  'epoxy': 299,
#  'three': 300,
#  'natural': 301,
#  'permanent': 302,
#  'suitable': 303,
#  'follows': 304,
#  'locations': 305,
#  'dispose': 306,
#  'bid': 307,
#  'equal': 308,
#  'longitudinal': 309,
#  'shape': 310,
#  'points': 311,
#  'item': 312,
#  'completion': 313,
#  'based': 314,
#  'standard': 315,
#  'smooth': 316,
#  'grouting': 317,
#  'far': 318,
#  'roller': 319,
#  'either': 320,
#  'curb': 321,
#  'details': 322,
#  'start': 323,
#  'protection': 324,
#  'min': 325,
#  'samples': 326,
#  'keep': 327,
#  'sample': 328,
#  'single': 329,
#  'uniformly': 330,
#  'walls': 331,
#  'height': 332,
#  'outside': 333,
#  'max': 334,
#  'ends': 335,
#  'process': 336,
#  'position': 337,
#  'slopes': 338,
#  'assembly': 339,
#  'conditions': 340,
#  'panel': 341,
#  'sampling': 342,
#  'coating': 343,
#  'contact': 344,
#  'edges': 345,
#  'parallel': 346,
#  'changes': 347,
#  'drilled': 348,
#  'plastic': 349,
#  'verify': 350,
#  'membrane': 351,
#  'alignment': 352,
#  'specific': 353,
#  'original': 354,
#  'plants': 355,
#  'see': 356,
#  'source': 357,
#  'kilograms': 358,
#  'weather': 359,
#  'systems': 360,
#  'yard': 361,
#  'measured': 362,
#  'information': 363,
#  'bar': 364,
#  'applied': 365,
#  'operation': 366,
#  'show': 367,
#  'lines': 368,
#  'volume': 369,
#  'correct': 370,
#  'removed': 371,
#  'jmf': 372,
#  'markings': 373,
#  'rollers': 374,
#  'entire': 375,
#  'nominal': 376,
#  'debris': 377,
#  'adjust': 378,
#  'accepted': 379,
#  'proper': 380,
#  'point': 381,
#  'cure': 382,
#  'driving': 383,
#  'obtain': 384,
#  'sign': 385,
#  'movement': 386,
#  'recommended': 387,
#  'crack': 388,
#  'finished': 389,
#  'filler': 390,
#  'check': 391,
#  'activities': 392,
#  'transverse': 393,
#  'paving': 394,
#  'tension': 395,
#  'dimensions': 396,
#  'quantities': 397,
#  'wood': 398,
#  'chloride': 399,
#  'stones': 400,
#  'high': 401,
#  'similar': 402,
#  'units': 403,
#  'discharge': 404,
#  'roughness': 405,
#  'begin': 406,
#  'layers': 407,
#  'lime': 408,
#  'amount': 409,
#  'wide': 410,
#  'part': 411,
#  'clause': 412,
#  'allowable': 413,
#  'performance': 414,
#  'mechanical': 415,
#  'sieve': 416,
#  'device': 417,
#  'corrosion': 418,
#  'specifications': 419,
#  'reference': 420,
#  'cracks': 421,
#  'open': 422,
#  'drive': 423,
#  'expansion': 424,
#  'written': 425,
#  'unit': 426,
#  'level': 427,
#  'lower': 428,
#  'aluminum': 429,
#  'crushed': 430,
#  'portion': 431,
#  'price': 432,
#  'lift': 433,
#  'profile': 434,
#  'verification': 435,
#  'drainage': 436,
#  'plus': 437,
#  'sealant': 438,
#  'resin': 439,
#  'around': 440,
#  'machine': 441,
#  'nail': 442,
#  'dust': 443,
#  'extend': 444,
#  'splices': 445,
#  'average': 446,
#  'impact': 447,
#  'cost': 448,
#  'sediment': 449,
#  'slab': 450,
#  'sheets': 451,
#  'mesh': 452,
#  'treated': 453,
#  'sheet': 454,
#  'nuts': 455,
#  'falsework': 456,
#  'avoid': 457,
#  'report': 458,
#  'measurement': 459,
#  'culvert': 460,
#  'installing': 461,
#  'measures': 462,
#  'trees': 463,
#  'connections': 464,
#  'filter': 465,
#  'subgrade': 466,
#  'take': 467,
#  'erection': 468,
#  'reinforced': 469,
#  'condition': 470,
#  'long': 471,
#  'dowel': 472,
#  'faces': 473,
#  'optimum': 474,
#  'heat': 475,
#  'fiber': 476,
#  'hammer': 477,
#  'listed': 478,
#  'non': 479,
#  'activity': 480,
#  'next': 481,
#  'liquid': 482,
#  'hot': 483,
#  'cleaning': 484,
#  'megapascals': 485,
#  'otherwise': 486,
#  'core': 487,
#  'excavate': 488,
#  'progress': 489,
#  'period': 490,
#  'galvanized': 491,
#  'supporting': 492,
#  'anchors': 493,
#  'performed': 494,
#  'sides': 495,
#  'removing': 496,
#  'spacing': 497,
#  'tendons': 498,
#  'larger': 499,
#  'mm': 500,
#  'meet': 501,
#  'prepared': 502,
#  'tube': 503,
#  'wet': 504,
#  'passes': 505,
#  'applying': 506,
#  'experience': 507,
#  'stabilized': 508,
#  'bearings': 509,
#  'space': 510,
#  'overlay': 511,
#  'tested': 512,
#  'stakes': 513,
#  'saw': 514,
#  'side': 515,
#  'beyond': 516,
#  'lot': 517,
#  'head': 518,
#  'follow': 519,
#  'special': 520,
#  'patch': 521,
#  'manner': 522,
#  'conduct': 523,
#  'straightedge': 524,
#  'sheeting': 525,
#  'hydraulic': 526,
#  'analysis': 527,
#  'hardware': 528,
#  'spread': 529,
#  'tie': 530,
#  'anchorage': 531,
#  'public': 532,
#  'stressing': 533,
#  'lane': 534,
#  'target': 535,
#  'seed': 536,
#  'state': 537,
#  'tensile': 538,
#  'thick': 539,
#  'identify': 540,
#  'direction': 541,
#  'hour': 542,
#  'vehicle': 543,
#  'voids': 544,
#  'cast': 545,
#  'fabrication': 546,
#  'deck': 547,
#  'prepare': 548,
#  'minutes': 549,
#  'elements': 550,
#  'solid': 551,
#  'loss': 552,
#  'sources': 553,
#  'admixtures': 554,
#  'spray': 555,
#  'drain': 556,
#  'includes': 557,
#  'topsoil': 558,
#  'cold': 559,
#  'fasten': 560,
#  'wires': 561,
#  'personnel': 562,
#  'paid': 563,
#  'box': 564,
#  'back': 565,
#  'preparation': 566,
#  'thoroughly': 567,
#  'fine': 568,
#  'clearing': 569,
#  'guardrail': 570,
#  'appropriate': 571,
#  'polymer': 572,
#  'defective': 573,
#  'driven': 574,
#  'certified': 575,
#  'member': 576,
#  'vegetation': 577,
#  'equipped': 578,
#  'jack': 579,
#  'inside': 580,
#  'cuts': 581,
#  'handling': 582,
#  'survey': 583,
#  'submittal': 584,
#  'match': 585,
#  'product': 586,
#  'roll': 587,
#  'add': 588,
#  'ash': 589,
#  'mulch': 590,
#  'compacted': 591,
#  'requested': 592,
#  'shafts': 593,
#  'securely': 594,
#  'stockpile': 595,
#  'center': 596,
#  'sod': 597,
#  'fibers': 598,
#  'permit': 599,
#  'dirt': 600,
#  'store': 601,
#  'casing': 602,
#  'rubble': 603,
#  'directed': 604,
#  'minimize': 605,
#  'facing': 606,
#  'dimension': 607,
#  'power': 608,
#  'sand': 609,
#  'direct': 610,
#  'true': 611,
#  'description': 612,
#  'filled': 613,
#  'fly': 614,
#  'loads': 615,
#  'gallon': 616,
#  'storage': 617,
#  'safety': 618,
#  'times': 619,
#  'preformed': 620,
#  'compacting': 621,
#  'bedding': 622,
#  'produced': 623,
#  'starting': 624,
#  'retroreflective': 625,
#  'record': 626,
#  'installed': 627,
#  'operate': 628,
#  'directly': 629,
#  'way': 630,
#  'types': 631,
#  'supports': 632,
#  'completely': 633,
#  'approximately': 634,
#  'splice': 635,
#  'ratio': 636,
#  'leave': 637,
#  'rates': 638,
#  'pipes': 639,
#  'temperatures': 640,
#  'whichever': 641,
#  'vibration': 642,
#  'overlap': 643,
#  'hand': 644,
#  'foreign': 645,
#  'controlled': 646,
#  'due': 647,
#  'outlet': 648,
#  'fit': 649,
#  'hold': 650,
#  'distance': 651,
#  'loading': 652,
#  'identification': 653,
#  'clear': 654,
#  'parts': 655,
#  'result': 656,
#  'cured': 657,
#  'drains': 658,
#  'upper': 659,
#  'dowels': 660,
#  'span': 661,
#  'pull': 662,
#  'trench': 663,
#  'stresses': 664,
#  'gate': 665,
#  'designed': 666,
#  'lay': 667,
#  'mill': 668,
#  'applications': 669,
#  'straight': 670,
#  'hauling': 671,
#  'markers': 672,
#  'barrier': 673,
#  'borrow': 674,
#  'prestressed': 675,
#  'block': 676,
#  'elongation': 677,
#  'covered': 678,
#  'components': 679,
#  'micropile': 680,
#  'showing': 681,
#  'lengths': 682,
#  'cell': 683,
#  'measurements': 684,
#  'attach': 685,
#  'delivery': 686,
#  'verified': 687,
#  'scale': 688,
#  'exceeding': 689,
#  'grouted': 690,
#  'plane': 691,
#  'manufactured': 692,
#  'welded': 693,
#  'glass': 694,
#  'minus': 695,
#  'constructing': 696,
#  'range': 697,
#  'calcium': 698,
#  'actual': 699,
#  'normal': 700,
#  'backfilling': 701,
#  'proof': 702,
#  'documentation': 703,
#  'washers': 704,
#  'road': 705,
#  'pins': 706,
#  'treatment': 707,
#  'stress': 708,
#  'coarse': 709,
#  'certifications': 710,
#  'mri': 711,
#  'containing': 712,
#  'separate': 713,
#  'culverts': 714,
#  'weld': 715,
#  'qualifications': 716,
#  'earth': 717,
#  'woven': 718,
#  'bed': 719,
#  'properly': 720,
#  'representative': 721,
#  'excavated': 722,
#  'ditches': 723,
#  'seals': 724,
#  'access': 725,
#  'demonstrate': 726,
#  'available': 727,
#  'fasteners': 728,
#  'positive': 729,
#  'shipment': 730,
#  'connection': 731,
#  'particles': 732,
#  'strand': 733,
#  'opening': 734,
#  'intended': 735,
#  'riprap': 736,
#  'film': 737,
#  'pound': 738,
#  'perpendicular': 739,
#  'deep': 740,
#  'front': 741,
#  'pattern': 742,
#  'pin': 743,
#  'rail': 744,
#  'permits': 745,
#  'code': 746,
#  'assemblies': 747,
#  'order': 748,
#  'sequence': 749,
#  'speed': 750,
#  'included': 751,
#  'tip': 752,
#  'indicate': 753,
#  'guardwall': 754,
#  'texture': 755,
#  'footing': 756,
#  'together': 757,
#  'achieve': 758,
#  'calculations': 759,
#  'half': 760,
#  'hard': 761,
#  'durable': 762,
#  'aggregates': 763,
#  'flat': 764,
#  'granular': 765,
#  'strands': 766,
#  'release': 767,
#  'federal': 768,
#  'regulations': 769,
#  'cause': 770,
#  'addition': 771,
#  'turf': 772,
#  'grading': 773,
#  'intervals': 774,
#  'weighing': 775,
#  'across': 776,
#  'anticipated': 777,
#  'inspect': 778,
#  'modified': 779,
#  'angles': 780,
#  'furnishing': 781,
#  'furnished': 782,
#  'horizontally': 783,
#  'liter': 784,
#  'remain': 785,
#  'permitted': 786,
#  'category': 787,
#  'composed': 788,
#  'cushion': 789,
#  'recp': 790,
#  'hammers': 791,
#  'unacceptable': 792,
#  'costs': 793,
#  'notify': 794,
#  'liters': 795,
#  'nozzle': 796,
#  'pass': 797,
#  'defined': 798,
#  'stability': 799,
#  'means': 800,
#  'cutting': 801,
#  'records': 802,
#  'brush': 803,
#  'flush': 804,
#  'another': 805,
#  'mark': 806,
#  'calculated': 807,
#  'jacking': 808,
#  'behind': 809,
#  'change': 810,
#  'products': 811,
#  'ultimate': 812,
#  'nails': 813,
#  'recycled': 814,
#  'vibratory': 815,
#  'added': 816,
#  'fully': 817,
#  'spreader': 818,
#  'bracing': 819,
#  'critical': 820,
#  'fittings': 821,
#  'gravity': 822,
#  'beads': 823,
#  'constructed': 824,
#  'tolerances': 825,
#  'working': 826,
#  'wma': 827,
#  'bands': 828,
#  'mixer': 829,
#  'established': 830,
#  'payments': 831,
#  'establishment': 832,
#  'baseline': 833,
#  'paper': 834,
#  'reports': 835,
#  'staking': 836,
#  'retaining': 837,
#  'every': 838,
#  'polyethylene': 839,
#  'ii': 840,
#  'remaining': 841,
#  'names': 842,
#  'resistant': 843,
#  'adhesive': 844,
#  'stop': 845,
#  'equivalent': 846,
#  'stabilization': 847,
#  'upon': 848,
#  'years': 849,
#  'tool': 850,
#  'occurs': 851,
#  'strips': 852,
#  'slabs': 853,
#  'review': 854,
#  'primer': 855,
#  'diameters': 856,
#  'dates': 857,
#  'pre': 858,
#  'failure': 859,
#  'piece': 860,
#  'continuously': 861,
#  'rigid': 862,
#  'guide': 863,
#  'geocomposite': 864,
#  'near': 865,
#  'current': 866,
#  'gallons': 867,
#  'travel': 868,
#  'continue': 869,
#  'short': 870,
#  'grinding': 871,
#  'select': 872,
#  'adjustments': 873,
#  'delay': 874,
#  'processed': 875,
#  'obtained': 876,
#  'kilogram': 877,
#  'threads': 878,
#  'shift': 879,
#  'broom': 880,
#  'projects': 881,
#  'revisions': 882,
#  'modifications': 883,
#  'copy': 884,
#  'deleterious': 885,
#  'waste': 886,
#  'evaluation': 887,
#  'laboratory': 888,
#  'rolling': 889,
#  'also': 890,
#  'electronic': 891,
#  'truck': 892,
#  'tolerance': 893,
#  'visible': 894,
#  'mechanically': 895,
#  'conduit': 896,
#  'highway': 897,
#  'property': 898,
#  'resistance': 899,
#  'moist': 900,
#  'beam': 901,
#  'excessive': 902,
#  'corrugated': 903,
#  'documents': 904,
#  'second': 905,
#  'features': 906,
#  'traveled': 907,
#  'batch': 908,
#  'needed': 909,
#  'treat': 910,
#  'right': 911,
#  'gravel': 912,
#  'hydration': 913,
#  'localized': 914,
#  'net': 915,
#  'double': 916,
#  'cage': 917,
#  'oil': 918,
#  'require': 919,
#  'gates': 920,
#  'additives': 921,
#  'curve': 922,
#  'taken': 923,
#  'mineral': 924,
#  'compound': 925,
#  'calibration': 926,
#  'mean': 927,
#  'bonded': 928,
#  'matrix': 929,
#  'evidence': 930,
#  'compressed': 931,
#  'filling': 932,
#  'sizes': 933,
#  'girders': 934,
#  'surety': 935,
#  'deflection': 936,
#  'exceeds': 937,
#  'maintaining': 938,
#  'iii': 939,
#  'expected': 940,
#  'encountered': 941,
#  'adequate': 942,
#  'facilities': 943,
#  'stumps': 944,
#  'pieces': 945,
#  'controls': 946,
#  'describe': 947,
#  'request': 948,
#  'percentage': 949,
#  'local': 950,
#  'reduce': 951,
#  'castinplace': 952,
#  'disposal': 953,
#  'consolidate': 954,
#  'handle': 955,
#  'last': 956,
#  'reset': 957,
#  'tables': 958,
#  'secure': 959,
#  'patching': 960,
#  'rejected': 961,
#  'shoulder': 962,
#  'supply': 963,
#  'terminal': 964,
#  'welding': 965,
#  'galvanize': 966,
#  'diagram': 967,
#  'component': 968,
#  'fixed': 969,
#  'foundations': 970,
#  'channel': 971,
#  'previously': 972,
#  'alternate': 973,
#  'mixes': 974,
#  'blend': 975,
#  'properties': 976,
#  'calibrated': 977,
#  'consisting': 978,
#  'action': 979,
#  'performing': 980,
#  'sound': 981,
#  'comply': 982,
#  'growth': 983,
#  'cannot': 984,
#  'tremie': 985,
#  'wheel': 986,
#  'pumping': 987,
#  'rod': 988,
#  'considered': 989,
#  'dynamic': 990,
#  'service': 991,
#  'submitted': 992,
#  'pressures': 993,
#  'marking': 994,
#  'chemical': 995,
#  'coated': 996,
#  'correction': 997,
#  'fhwa': 998,
#  'rap': 999,
#  'resetting': 1000,
#  ...}

# %%
#단어 사전과 전체 단어 개수 저장 

data_configs={}

data_configs['vocab'] = word_vocab
data_configs['vocab_size'] = len(word_vocab)+1

# %%
print("전체 단어 개수: ", len(word_vocab))
# Out:
# 전체 단어 개수:  6806

# %% [markdown]
# * 각 clause 를 모두 단어 인덱스화 한 text_sequences를 전체 트레이닝 데이터의 크기를 168(평균값) 에 맞춰서 앞뒤로 0 패딩해줘야 한다.

# %%
train_inputs = pad_sequences(text_sequences, maxlen=175, padding='post')

print('shape of train data: ', train_inputs.shape)
# Out:
# shape of train data:  (4057, 175)

# %% [markdown]
# * 정답을 나타내는 라벨도 넘파이배열로 저장한다.

# %%
train_labels = np.array(input_text['label'])

print('shape of traib labels: ', train_labels.shape)
# Out:
# shape of traib labels:  (4057,)

# %%
train_Input_data='train_input.npy'
train_label_data='train_label.npy'
train_clean_data='train_clean.csv'
data_config = 'data_config.json'


np.save(open(dataOutPath+ train_Input_data, 'wb'), train_inputs)
np.save(open(dataOutPath+ train_label_data, 'wb'), train_labels)

clean_input_df.to_csv(dataOutPath+train_clean_data, index=False)

json.dump(data_config, open(dataOutPath+data_config, 'w'), ensure_ascii=False)

# %% [markdown]
# 여기까지 아직 테스트셋 안만들었음
